# %% [markdown]
# # Read Data

# %%
from src.logage2026.loading import *
from src.logage2026.cleaning import clean_sku_master

# %%
dist_df = load_distributors()

sku_df = load_sku_master()

trans_df = load_transactions()

# %%
sku_df = clean_sku_master(sku_df)
sku_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1324 entries, 0 to 1327
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sku_code              1324 non-null   string
#  1   sap_code              651 non-null    string
#  2   sap_code_2            1324 non-null   string
#  3   updated_date          645 non-null    datetime64[ns]
#  4   sku_row_no            1296 non-null   string
#  5   type                  1324 non-null   string
#  6   com_code              1324 non-null   string
#  7   product_name          1324 non-null   string
#  8   unit                  1281 non-null   string
#  9   category              1324 non-null   string
#  10  pcs_per_carton        1324 non-null   Int64
#  11  carton_length_mm      1294 non-null   Int64
#  12  carton_width_mm       1294 non-null   Int64
#  13  carton_height_mm      1294 non-null   Int64
#  14  pcs_per_pallet        1238 non-null   Int64
# ...

# %%
sku_df.describe()
# Out:
#                         updated_date  pcs_per_carton  carton_length_mm  \
# count                            645          1324.0            1294.0
# mean   2020-06-13 22:39:37.674418432        3.993202        484.416538
# min              2020-05-22 00:00:00             1.0               0.0
# 25%              2020-05-22 00:00:00             1.0             410.0
# 50%              2020-05-22 00:00:00             2.0             470.0
# 75%              2020-06-02 00:00:00             6.0             550.0
# max              2020-12-14 00:00:00            64.0            1620.0
# std                              NaN        5.288712        115.936813
#
#        carton_width_mm  carton_height_mm  pcs_per_pallet  cartons_per_layer  \
# count           1294.0            1294.0          1238.0             1126.0
# mean        304.823029        376.089645      118.946688           5.988455
# min                0.0               0.0             0.0                0.0
# ...
